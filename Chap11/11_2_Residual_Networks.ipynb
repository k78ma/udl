# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  # def forward(self, x):
  #   h1 = self.linear1(x).relu()
  #   h2 = self.linear2(h1).relu()
  #   h3 = self.linear3(h2).relu()
  #   return self.linear4(h3)

  def forward(self, x):
    h0 = self.linear1(x)
    h1 = h0 + self.linear2(torch.relu(h0)) 
    h2 = h1 + self.linear3(torch.relu(h1))
    y = self.linear4(h2)
    return y

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.681574, train error 60.85,  val loss 1.827839, percent error 63.80
# Epoch     1, train loss 1.267662, train error 47.80,  val loss 1.439085, percent error 54.20
# Epoch     2, train loss 1.043647, train error 40.47,  val loss 1.244202, percent error 48.70
# Epoch     3, train loss 0.918307, train error 34.78,  val loss 1.201657, percent error 45.30
# Epoch     4, train loss 0.828223, train error 31.25,  val loss 1.175051, percent error 43.20
# Epoch     5, train loss 0.874106, train error 32.47,  val loss 1.351547, percent error 45.80
# Epoch     6, train loss 0.712983, train error 26.72,  val loss 1.192207, percent error 43.90
# Epoch     7, train loss 0.635258, train error 23.97,  val loss 1.243951, percent error 42.20
# Epoch     8, train loss 0.612733, train error 22.75,  val loss 1.289001, percent error 42.40
# Epoch     9, train loss 0.563718, train error 21.82,  val loss 1.251421, percent error 40.10
# Epoch    10, train loss 0.504825, train error 19.07,  val loss 1.181255, percent error 39.00
# Epoch    11, train loss 0.414609, train error 15.30,  val loss 1.197119, percent error 40.40
# Epoch    12, train loss 0.398444, train error 14.45,  val loss 1.278228, percent error 38.50
# Epoch    13, train loss 0.380506, train error 13.70,  val loss 1.259714, percent error 37.40
# Epoch    14, train loss 0.393143, train error 14.15,  val loss 1.400738, percent error 37.70
# Epoch    15, train loss 0.387991, train error 14.07,  val loss 1.441537, percent error 40.30
# Epoch    16, train loss 0.292495, train error 10.62,  val loss 1.260399, percent error 34.70
# Epoch    17, train loss 0.271415, train error 10.32,  val loss 1.323171, percent error 34.50
# Epoch    18, train loss 0.325262, train error 12.10,  val loss 1.664423, percent error 38.50
# Epoch    19, train loss 0.315135, train error 11.30,  val loss 1.588128, percent error 37.20
# Epoch    20, train loss 0.081170, train error 2.45,  val loss 1.307481, percent error 32.90
# Epoch    21, train loss 0.045536, train error 0.72,  val loss 1.275177, percent error 30.70
# Epoch    22, train loss 0.028812, train error 0.20,  val loss 1.313793, percent error 31.00
# Epoch    23, train loss 0.018623, train error 0.05,  val loss 1.316760, percent error 32.10
# Epoch    24, train loss 0.013729, train error 0.00,  val loss 1.332408, percent error 31.70
# Epoch    25, train loss 0.011406, train error 0.00,  val loss 1.358927, percent error 31.90
# Epoch    26, train loss 0.009770, train error 0.00,  val loss 1.382275, percent error 31.50
# Epoch    27, train loss 0.008570, train error 0.00,  val loss 1.409244, percent error 31.70
# Epoch    28, train loss 0.007649, train error 0.00,  val loss 1.430056, percent error 31.80
# Epoch    29, train loss 0.007028, train error 0.00,  val loss 1.447709, percent error 31.90
# Epoch    30, train loss 0.006304, train error 0.00,  val loss 1.463158, percent error 32.00
# Epoch    31, train loss 0.005785, train error 0.00,  val loss 1.478154, percent error 31.80
# Epoch    32, train loss 0.005390, train error 0.00,  val loss 1.486896, percent error 31.50
# Epoch    33, train loss 0.004975, train error 0.00,  val loss 1.502846, percent error 31.90
# Epoch    34, train loss 0.004638, train error 0.00,  val loss 1.517244, percent error 32.00
# Epoch    35, train loss 0.004346, train error 0.00,  val loss 1.530571, percent error 31.80
# Epoch    36, train loss 0.004090, train error 0.00,  val loss 1.541978, percent error 31.80
# Epoch    37, train loss 0.003864, train error 0.00,  val loss 1.551853, percent error 31.60
# Epoch    38, train loss 0.003661, train error 0.00,  val loss 1.562103, percent error 31.50
# Epoch    39, train loss 0.003474, train error 0.00,  val loss 1.572821, percent error 31.90
# Epoch    40, train loss 0.003385, train error 0.00,  val loss 1.578209, percent error 31.90
# Epoch    41, train loss 0.003304, train error 0.00,  val loss 1.582771, percent error 31.80
# Epoch    42, train loss 0.003227, train error 0.00,  val loss 1.587066, percent error 31.90
# Epoch    43, train loss 0.003155, train error 0.00,  val loss 1.590771, percent error 31.80
# Epoch    44, train loss 0.003085, train error 0.00,  val loss 1.595502, percent error 31.70
# Epoch    45, train loss 0.003019, train error 0.00,  val loss 1.600133, percent error 31.70
# Epoch    46, train loss 0.002956, train error 0.00,  val loss 1.603639, percent error 31.80
# Epoch    47, train loss 0.002894, train error 0.00,  val loss 1.608197, percent error 31.90
# Epoch    48, train loss 0.002835, train error 0.00,  val loss 1.612299, percent error 31.90
# Epoch    49, train loss 0.002778, train error 0.00,  val loss 1.616433, percent error 31.90
# Epoch    50, train loss 0.002722, train error 0.00,  val loss 1.619789, percent error 31.80
# Epoch    51, train loss 0.002671, train error 0.00,  val loss 1.623777, percent error 31.90
# Epoch    52, train loss 0.002620, train error 0.00,  val loss 1.627528, percent error 31.90
# Epoch    53, train loss 0.002571, train error 0.00,  val loss 1.631133, percent error 31.90
# Epoch    54, train loss 0.002525, train error 0.00,  val loss 1.636041, percent error 31.90
# Epoch    55, train loss 0.002478, train error 0.00,  val loss 1.639735, percent error 31.80
# Epoch    56, train loss 0.002434, train error 0.00,  val loss 1.643091, percent error 31.70
# Epoch    57, train loss 0.002391, train error 0.00,  val loss 1.646387, percent error 31.90
# Epoch    58, train loss 0.002350, train error 0.00,  val loss 1.649283, percent error 31.80
# Epoch    59, train loss 0.002310, train error 0.00,  val loss 1.653341, percent error 31.90
# Epoch    60, train loss 0.002290, train error 0.00,  val loss 1.654841, percent error 31.80
# Epoch    61, train loss 0.002271, train error 0.00,  val loss 1.657133, percent error 31.80
# Epoch    62, train loss 0.002252, train error 0.00,  val loss 1.658364, percent error 31.70
# Epoch    63, train loss 0.002233, train error 0.00,  val loss 1.660096, percent error 31.70
# Epoch    64, train loss 0.002215, train error 0.00,  val loss 1.661776, percent error 31.70
# Epoch    65, train loss 0.002197, train error 0.00,  val loss 1.663410, percent error 31.70
# Epoch    66, train loss 0.002180, train error 0.00,  val loss 1.664902, percent error 31.70
# Epoch    67, train loss 0.002162, train error 0.00,  val loss 1.666469, percent error 31.70
# Epoch    68, train loss 0.002146, train error 0.00,  val loss 1.668521, percent error 31.70
# Epoch    69, train loss 0.002129, train error 0.00,  val loss 1.670091, percent error 31.70
# Epoch    70, train loss 0.002112, train error 0.00,  val loss 1.671490, percent error 31.70
# Epoch    71, train loss 0.002095, train error 0.00,  val loss 1.673037, percent error 31.70
# Epoch    72, train loss 0.002080, train error 0.00,  val loss 1.674426, percent error 31.70
# Epoch    73, train loss 0.002063, train error 0.00,  val loss 1.676254, percent error 31.70
# Epoch    74, train loss 0.002048, train error 0.00,  val loss 1.677792, percent error 31.70
# Epoch    75, train loss 0.002032, train error 0.00,  val loss 1.679204, percent error 31.70
# Epoch    76, train loss 0.002017, train error 0.00,  val loss 1.680442, percent error 31.70
# Epoch    77, train loss 0.002002, train error 0.00,  val loss 1.682134, percent error 31.70
# Epoch    78, train loss 0.001987, train error 0.00,  val loss 1.683857, percent error 31.80
# Epoch    79, train loss 0.001972, train error 0.00,  val loss 1.685279, percent error 31.70
# Epoch    80, train loss 0.001965, train error 0.00,  val loss 1.685848, percent error 31.80
# Epoch    81, train loss 0.001958, train error 0.00,  val loss 1.686779, percent error 31.80
# Epoch    82, train loss 0.001950, train error 0.00,  val loss 1.687402, percent error 31.80
# Epoch    83, train loss 0.001943, train error 0.00,  val loss 1.688308, percent error 31.80
# Epoch    84, train loss 0.001936, train error 0.00,  val loss 1.688931, percent error 31.80
# Epoch    85, train loss 0.001929, train error 0.00,  val loss 1.689573, percent error 31.80
# Epoch    86, train loss 0.001922, train error 0.00,  val loss 1.690462, percent error 31.80
# Epoch    87, train loss 0.001916, train error 0.00,  val loss 1.691202, percent error 31.80
# Epoch    88, train loss 0.001909, train error 0.00,  val loss 1.691893, percent error 31.80
# Epoch    89, train loss 0.001902, train error 0.00,  val loss 1.692301, percent error 31.80
# Epoch    90, train loss 0.001895, train error 0.00,  val loss 1.693272, percent error 31.80
# Epoch    91, train loss 0.001889, train error 0.00,  val loss 1.693819, percent error 31.80
# Epoch    92, train loss 0.001882, train error 0.00,  val loss 1.694547, percent error 31.80
# Epoch    93, train loss 0.001875, train error 0.00,  val loss 1.695366, percent error 31.80
# Epoch    94, train loss 0.001869, train error 0.00,  val loss 1.696097, percent error 31.80
# Epoch    95, train loss 0.001862, train error 0.00,  val loss 1.696843, percent error 31.80
# Epoch    96, train loss 0.001856, train error 0.00,  val loss 1.697521, percent error 31.80
# Epoch    97, train loss 0.001849, train error 0.00,  val loss 1.698320, percent error 31.80
# Epoch    98, train loss 0.001843, train error 0.00,  val loss 1.699016, percent error 31.80
# Epoch    99, train loss 0.001836, train error 0.00,  val loss 1.699577, percent error 31.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
