# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
# model = nn.Sequential(
# nn.Flatten(),
# nn.Linear(40, 100),
# nn.ReLU(),
# nn.Linear(100, 100),
# nn.ReLU(),
# nn.Linear(100, 10))

model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding='valid'),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding='valid'),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding='valid'),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(in_features=60, out_features=10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.022162, train error 77.55,  val loss 2.041315, percent error 77.10
# Epoch     1, train loss 1.493840, train error 60.97,  val loss 1.513596, percent error 63.90
# Epoch     2, train loss 1.417407, train error 56.30,  val loss 1.432235, percent error 58.50
# Epoch     3, train loss 1.267261, train error 51.38,  val loss 1.290299, percent error 54.60
# Epoch     4, train loss 1.179615, train error 48.30,  val loss 1.209209, percent error 50.60
# Epoch     5, train loss 1.084718, train error 43.92,  val loss 1.134521, percent error 46.10
# Epoch     6, train loss 1.012675, train error 41.58,  val loss 1.087520, percent error 46.20
# Epoch     7, train loss 0.924461, train error 36.85,  val loss 1.009699, percent error 41.40
# Epoch     8, train loss 0.884557, train error 36.47,  val loss 0.971840, percent error 39.80
# Epoch     9, train loss 0.815289, train error 32.55,  val loss 0.905744, percent error 36.10
# Epoch    10, train loss 0.712534, train error 28.53,  val loss 0.814126, percent error 33.40
# Epoch    11, train loss 0.640513, train error 25.93,  val loss 0.729923, percent error 31.20
# Epoch    12, train loss 0.628483, train error 24.80,  val loss 0.730550, percent error 28.50
# Epoch    13, train loss 0.540357, train error 20.97,  val loss 0.645274, percent error 26.90
# Epoch    14, train loss 0.514959, train error 18.95,  val loss 0.610765, percent error 23.30
# Epoch    15, train loss 0.505423, train error 18.50,  val loss 0.642757, percent error 22.20
# Epoch    16, train loss 0.400707, train error 14.05,  val loss 0.484516, percent error 17.50
# Epoch    17, train loss 0.321798, train error 11.10,  val loss 0.430976, percent error 15.10
# Epoch    18, train loss 0.264387, train error 8.95,  val loss 0.372282, percent error 12.80
# Epoch    19, train loss 0.253526, train error 8.68,  val loss 0.378346, percent error 12.90
# Epoch    20, train loss 0.219406, train error 7.82,  val loss 0.382432, percent error 12.50
# Epoch    21, train loss 0.185770, train error 6.18,  val loss 0.325972, percent error 11.40
# Epoch    22, train loss 0.180848, train error 6.38,  val loss 0.338900, percent error 12.30
# Epoch    23, train loss 0.156390, train error 5.00,  val loss 0.334342, percent error 11.20
# Epoch    24, train loss 0.177547, train error 6.10,  val loss 0.369210, percent error 12.80
# Epoch    25, train loss 0.144601, train error 4.80,  val loss 0.339583, percent error 11.30
# Epoch    26, train loss 0.136915, train error 4.60,  val loss 0.330271, percent error 9.50
# Epoch    27, train loss 0.143104, train error 5.22,  val loss 0.331609, percent error 10.30
# Epoch    28, train loss 0.132417, train error 4.35,  val loss 0.344995, percent error 11.20
# Epoch    29, train loss 0.155366, train error 5.62,  val loss 0.409506, percent error 11.30
# Epoch    30, train loss 0.124765, train error 4.20,  val loss 0.336348, percent error 10.60
# Epoch    31, train loss 0.114701, train error 3.65,  val loss 0.338758, percent error 11.20
# Epoch    32, train loss 0.104436, train error 3.50,  val loss 0.338574, percent error 10.20
# Epoch    33, train loss 0.097545, train error 3.20,  val loss 0.351764, percent error 10.20
# Epoch    34, train loss 0.092701, train error 2.72,  val loss 0.351429, percent error 11.10
# Epoch    35, train loss 0.136337, train error 4.80,  val loss 0.366818, percent error 10.60
# Epoch    36, train loss 0.117247, train error 4.12,  val loss 0.350436, percent error 10.40
# Epoch    37, train loss 0.103774, train error 3.43,  val loss 0.370171, percent error 10.80
# Epoch    38, train loss 0.087473, train error 2.78,  val loss 0.351255, percent error 10.50
# Epoch    39, train loss 0.090898, train error 3.25,  val loss 0.370145, percent error 10.00
# Epoch    40, train loss 0.071563, train error 2.00,  val loss 0.348851, percent error 9.60
# Epoch    41, train loss 0.073607, train error 2.15,  val loss 0.344927, percent error 10.00
# Epoch    42, train loss 0.065111, train error 1.68,  val loss 0.370194, percent error 10.20
# Epoch    43, train loss 0.062608, train error 1.70,  val loss 0.363103, percent error 9.30
# Epoch    44, train loss 0.061474, train error 1.80,  val loss 0.358415, percent error 9.70
# Epoch    45, train loss 0.064754, train error 1.70,  val loss 0.357147, percent error 9.20
# Epoch    46, train loss 0.065453, train error 1.95,  val loss 0.358148, percent error 9.20
# Epoch    47, train loss 0.060467, train error 1.70,  val loss 0.351349, percent error 9.00
# Epoch    48, train loss 0.056528, train error 1.45,  val loss 0.370467, percent error 9.50
# Epoch    49, train loss 0.062575, train error 1.93,  val loss 0.360396, percent error 9.40
# Epoch    50, train loss 0.056726, train error 1.55,  val loss 0.372118, percent error 10.30
# Epoch    51, train loss 0.053687, train error 1.47,  val loss 0.384485, percent error 9.90
# Epoch    52, train loss 0.053944, train error 1.45,  val loss 0.382541, percent error 9.50
# Epoch    53, train loss 0.050027, train error 1.35,  val loss 0.390545, percent error 9.90
# Epoch    54, train loss 0.059962, train error 1.80,  val loss 0.378701, percent error 10.00
# Epoch    55, train loss 0.048539, train error 1.20,  val loss 0.384166, percent error 10.00
# Epoch    56, train loss 0.049395, train error 1.15,  val loss 0.405378, percent error 9.90
# Epoch    57, train loss 0.050509, train error 1.40,  val loss 0.399219, percent error 9.40
# Epoch    58, train loss 0.053519, train error 1.60,  val loss 0.380136, percent error 9.50
# Epoch    59, train loss 0.047471, train error 1.15,  val loss 0.397069, percent error 9.60
# Epoch    60, train loss 0.042756, train error 0.97,  val loss 0.387729, percent error 9.70
# Epoch    61, train loss 0.041470, train error 1.00,  val loss 0.397402, percent error 9.60
# Epoch    62, train loss 0.040721, train error 0.78,  val loss 0.391329, percent error 10.00
# Epoch    63, train loss 0.041411, train error 0.97,  val loss 0.393199, percent error 9.60
# Epoch    64, train loss 0.040182, train error 0.95,  val loss 0.389554, percent error 9.60
# Epoch    65, train loss 0.039271, train error 0.78,  val loss 0.401276, percent error 9.70
# Epoch    66, train loss 0.039544, train error 0.93,  val loss 0.409942, percent error 9.70
# Epoch    67, train loss 0.038779, train error 0.80,  val loss 0.399651, percent error 9.70
# Epoch    68, train loss 0.039658, train error 0.85,  val loss 0.406960, percent error 9.60
# Epoch    69, train loss 0.038109, train error 0.82,  val loss 0.400668, percent error 9.70
# Epoch    70, train loss 0.037758, train error 0.85,  val loss 0.402015, percent error 10.20
# Epoch    71, train loss 0.036816, train error 0.72,  val loss 0.405602, percent error 10.20
# Epoch    72, train loss 0.039755, train error 0.97,  val loss 0.407722, percent error 9.80
# Epoch    73, train loss 0.037939, train error 0.78,  val loss 0.419041, percent error 10.20
# Epoch    74, train loss 0.037426, train error 0.75,  val loss 0.413888, percent error 10.00
# Epoch    75, train loss 0.035425, train error 0.75,  val loss 0.415028, percent error 9.90
# Epoch    76, train loss 0.035522, train error 0.70,  val loss 0.407538, percent error 10.00
# Epoch    77, train loss 0.034832, train error 0.70,  val loss 0.417799, percent error 9.80
# Epoch    78, train loss 0.039443, train error 0.95,  val loss 0.402866, percent error 9.60
# Epoch    79, train loss 0.034317, train error 0.65,  val loss 0.423004, percent error 10.00
# Epoch    80, train loss 0.034086, train error 0.68,  val loss 0.413100, percent error 9.90
# Epoch    81, train loss 0.033926, train error 0.62,  val loss 0.427162, percent error 10.00
# Epoch    82, train loss 0.032909, train error 0.62,  val loss 0.420189, percent error 9.80
# Epoch    83, train loss 0.033678, train error 0.68,  val loss 0.413141, percent error 9.90
# Epoch    84, train loss 0.033796, train error 0.72,  val loss 0.412426, percent error 9.80
# Epoch    85, train loss 0.032312, train error 0.62,  val loss 0.422284, percent error 10.10
# Epoch    86, train loss 0.032466, train error 0.70,  val loss 0.423047, percent error 10.10
# Epoch    87, train loss 0.032067, train error 0.68,  val loss 0.423008, percent error 9.80
# Epoch    88, train loss 0.032160, train error 0.62,  val loss 0.417232, percent error 9.90
# Epoch    89, train loss 0.032343, train error 0.62,  val loss 0.430663, percent error 10.00
# Epoch    90, train loss 0.032297, train error 0.62,  val loss 0.433131, percent error 10.00
# Epoch    91, train loss 0.033775, train error 0.68,  val loss 0.442959, percent error 10.10
# Epoch    92, train loss 0.032130, train error 0.72,  val loss 0.425762, percent error 10.00
# Epoch    93, train loss 0.031080, train error 0.57,  val loss 0.424143, percent error 10.10
# Epoch    94, train loss 0.031680, train error 0.62,  val loss 0.429614, percent error 9.90
# Epoch    95, train loss 0.030606, train error 0.62,  val loss 0.426881, percent error 10.00
# Epoch    96, train loss 0.031496, train error 0.53,  val loss 0.440051, percent error 9.90
# Epoch    97, train loss 0.030464, train error 0.53,  val loss 0.426887, percent error 9.90
# Epoch    98, train loss 0.030208, train error 0.60,  val loss 0.427133, percent error 9.90
# Epoch    99, train loss 0.030182, train error 0.60,  val loss 0.434399, percent error 10.00
